# %%
import requests
import gzip
import networkx as nx
import io

def get_hepph_graph():
    # Step 1: Download the .gz file
    url = 'https://snap.stanford.edu/data/cit-HepPh.txt.gz'
    response = requests.get(url)
    response.raise_for_status()  # Check that the request was successful

    # Step 2: Unzip the file
    with gzip.open(io.BytesIO(response.content), 'rt') as f:
        # Step 3: Parse the contents and create the graph
        G = nx.DiGraph()
        for line in f:
            if line.startswith('#'):
                continue  # Skip comment lines
            from_node, to_node = line.strip().split()
            G.add_edge(from_node, to_node)

    return G

# Example usage:
hepph_graph = get_hepph_graph()

mapping = {old_label: new_label for new_label, old_label in enumerate(hepph_graph.nodes())}
G = nx.relabel_nodes(hepph_graph, mapping)

print(G)
# Out:
# DiGraph with 34546 nodes and 421578 edges

# %%
assert sorted(G.nodes) == list(range(G.number_of_nodes()))

# %%
from scipy.sparse.linalg import eigs
import numpy as np

from randcolorgraphs.utils.calculate_katz import calculate_katz

def get_adj_and_katz(G, alpha=0.1, beta=1.0):
    A_G = nx.adjacency_matrix(G).astype(np.float64)

    eigenvalues, _ = eigs(A_G, k=1, which='LM')  # 'LM': Largest Magnitude, tol is tolerance
    spectral_radius_G = np.abs(eigenvalues).max()
    print(f"Spectral Radius: {spectral_radius_G}, alpha_max = {1/spectral_radius_G}")
    print("calculating katz centrality")
    katz_centrality = calculate_katz(A_G, alpha = alpha, beta=beta)
    print("done calculating katz")

    # Reorder nodes based on Katz centrality
    sorted_indices = np.argsort(katz_centrality)
    sorted_nodes = np.array(G.nodes())[sorted_indices]

    # Generate the adjacency matrix
    adj_matrix = nx.adjacency_matrix(G, nodelist=sorted_nodes)

    sorted_katz_vector = katz_centrality[sorted_indices]

    assert np.allclose(sorted_katz_vector, calculate_katz(adj_matrix.astype(np.float64), alpha = alpha, beta=beta))
    return adj_matrix, sorted_katz_vector

# %%
A_G, katz_centrality = get_adj_and_katz(G, alpha = 0.03)
A_G_dense = A_G.todense()

print("katz vector mean and max", np.mean(katz_centrality), np.max(katz_centrality))
# Out:
# Spectral Radius: 5.662920319737484, alpha_max = 0.17658733366150506
# calculating katz centrality
# Katz converged after 25 iterations.
# done calculating katz
# Katz converged after 25 iterations.
# katz vector mean and max 1.649706382561998 28.68418325734212

# %%
import kmeans1d

from randcolorgraphs.objectives.get_cluster_loss_ell_sqr import get_cluster_loss_ell_sqr
from randcolorgraphs.objectives.get_expected_edgeoverlap import get_expected_edgeoverlap
from randcolorgraphs.algorithms.linear_scalarization.optimal_contiguous.optimal_contiguous_linear_scalarization_algo import optimal_contiguous_linear_scalarization_algo
import pandas as pd

from fast_pareto import is_pareto_front

def evaluate_cluster_assignment(katz_centrality, A, clusters):
    ell_sqr = get_cluster_loss_ell_sqr(katz_centrality, clusters)
    expected_edge_overlap = get_expected_edgeoverlap(A, clusters)
    return [ell_sqr, expected_edge_overlap]

### Analyze all possible clusters for their performance regarding specific merics and booleans
df = pd.DataFrame(columns=["ell_sqr", "expected_edge_overlap", "method_type"])

for k in range(1, 20, 1):
    print(f"Doing k={k}")
    colors, _ = kmeans1d.cluster(katz_centrality, k)
    clusters = np.array(colors)
    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Kmeans1d (k={k}) on Katz centrality"]

for k in range(35, 700, 30):
    print(f"Doing k={k}")
    colors, _ = kmeans1d.cluster(katz_centrality, k)
    clusters = np.array(colors)
    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Kmeans1d (k={k}) on Katz centrality"]
# Out:
# Doing k=1
# Doing k=2
# Doing k=3
# Doing k=4
# Doing k=5
# Doing k=6
# Doing k=7
# Doing k=8
# Doing k=9
# Doing k=10
# Doing k=11
# Doing k=12
# Doing k=13
# Doing k=14
# Doing k=15
# Doing k=16
# Doing k=17
# Doing k=18
# Doing k=19
# Doing k=35
# Doing k=65
# Doing k=95
# Doing k=125
# Doing k=155
# Doing k=185
# Doing k=215
# Doing k=245
# Doing k=275
# Doing k=305
# Doing k=335
# Doing k=365
# Doing k=395
# Doing k=425
# Doing k=455
# Doing k=485
# Doing k=515
# Doing k=545
# Doing k=575
# Doing k=605
# Doing k=635
# Doing k=665
# Doing k=695

# %%
# OUT OF MEMORY
#for w in np.exp(-np.linspace(-1,12,3)):
#    clusters = optimal_contiguous_linear_scalarization_algo(katz_centrality, A_G_dense, w)
#    print(f"Done w={w}")
#    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Opt. Cont. Scal. (w={w})"]

# %%
#from greedy_algo_fast import greedy_search
#import scipy.sparse as sp
#
#def get_edge_vector_from_adj_matrix(adj_matrix):
#    sparse_matrix = sp.csr_matrix(adj_matrix)
#    row_indices, col_indices = sparse_matrix.nonzero()
#    edge_vector = np.vstack((row_indices, col_indices)).T
#    return edge_vector
#
#edges = get_edge_vector_from_adj_matrix(A_G)
#
#for w in np.exp(-np.linspace(-1,12,3)):
#    clusters, _ = greedy_search(katz_centrality, edges, np.array([0]*len(katz_centrality)), w=w, max_interaction_dist=1, max_iter=400)
#    print(f"Done w={w}")
#    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Greedy Search (w={w})"]

# %%
import pandas as pd

from greedy_algo_fast import greedy_search
import scipy.sparse as sp


def find_optimal_start_k(df, w):
    kmeans_rows = df[df['method_type'].str.contains(r'Kmeans1d \(k=')]
    obj = kmeans_rows['ell_sqr'] + w * kmeans_rows['expected_edge_overlap']
    min_index = obj.idxmin()
    method_type = kmeans_rows.loc[min_index, 'method_type']
    k = int(method_type.split('Kmeans1d (k=')[1].split(')')[0])
    return k

def get_edge_vector_from_adj_matrix(adj_matrix):
    sparse_matrix = sp.csr_matrix(adj_matrix)
    row_indices, col_indices = sparse_matrix.nonzero()
    edge_vector = np.vstack((row_indices, col_indices)).T
    return edge_vector

edges = get_edge_vector_from_adj_matrix(A_G)

for w in [0.005, 0.0005, 0.00005]:
    optimal_k = find_optimal_start_k(df, w)

    print(f'The optimal k for (w={w}) is: {optimal_k}')
    colors, _ = kmeans1d.cluster(katz_centrality, k)
    clusters = np.array(colors)

    print("Doing dist=1")
    clusters, _ = greedy_search(katz_centrality, edges, clusters, w=w, max_interaction_dist=1, max_iter=10_000)
    print("Doing dist=2")
    clusters, _ = greedy_search(katz_centrality, edges, clusters, w=w, max_interaction_dist=2, max_iter=10_000)
    print("Doing dist=3")
    clusters, _ = greedy_search(katz_centrality, edges, clusters, w=w, max_interaction_dist=2, max_iter=10_000)
    print(f"Done w={w}")
    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Warm Start Greedy Search (w={w})"]
# Out:
# The optimal k for (w=0.005) is: 125
# Doing dist=1
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 591 that was deleted!
# !!!
# Iteration 0 Objective: 55.0127853087929 move_type merge-split expected_edge_overlap 10987.644542161821
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 588 that was deleted!
# !!!
# Iteration 1 Objective: 54.386042130841446 move_type merge-split expected_edge_overlap 10862.144542161821
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 600 that was deleted!
# !!!
# Iteration 2 Objective: 53.91801873937263 move_type merge-split expected_edge_overlap 10768.44454216182
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 589 that was deleted!
# !!!
# Iteration 3 Objective: 53.59787054488814 move_type merge-split expected_edge_overlap 10703.87311359039
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 590 that was deleted!
# !!!
# Iteration 4 Objective: 53.210607268787186 move_type merge-split expected_edge_overlap 10624.512723980002
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 658 that was deleted!
# !!!
# Iteration 5 Objective: 52.95738965378305 move_type merge-split expected_edge_overlap 10573.512723980002
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 599 that was deleted!
# !!!
# Iteration 6 Objective: 52.730568248705794 move_type merge-split expected_edge_overlap 10527.879390646669
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 534 that was deleted!
# !!!
# Iteration 7 Objective: 52.514432500607256 move_type merge-split expected_edge_overlap 10484.593676360955
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 535 that was deleted!
# !!!
# Iteration 8 Objective: 52.29668185785761 move_type merge-split expected_edge_overlap 10440.762723980004
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 514 that was deleted!
# !!!
# Iteration 9 Objective: 52.09364155740212 move_type merge-split expected_edge_overlap 10400.046057313337
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 460 that was deleted!
# !!!
# Iteration 10 Objective: 51.89572230637259 move_type merge-split expected_edge_overlap 10360.268279535558
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 568 that was deleted!
# !!!
# Iteration 11 Objective: 51.70008445142122 move_type merge-split expected_edge_overlap 10320.868279535558
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 508 that was deleted!
# !!!
# Iteration 12 Objective: 51.50625612991911 move_type merge-split expected_edge_overlap 10281.70161286889
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 654 that was deleted!
# !!!
# Iteration 13 Objective: 51.33352748364467 move_type merge-split expected_edge_overlap 10245.368279535556
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 655 that was deleted!
# !!!
# Iteration 14 Objective: 51.15280160844844 move_type merge-split expected_edge_overlap 10207.70161286889
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 601 that was deleted!
# !!!
# Iteration 15 Objective: 50.98413517270518 move_type merge-split expected_edge_overlap 10173.677803345081
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 615 that was deleted!
# !!!
# Iteration 16 Objective: 50.82007707401894 move_type merge-split expected_edge_overlap 10140.511136678415
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 432 that was deleted!
# !!!
# Iteration 17 Objective: 50.66271445403592 move_type merge-split expected_edge_overlap 10108.875825230603
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 638 that was deleted!
# !!!
# Iteration 18 Objective: 50.50949610389134 move_type merge-split expected_edge_overlap 10077.875825230603
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 681 that was deleted!
# !!!
# Iteration 19 Objective: 50.36220809800463 move_type merge-split expected_edge_overlap 10044.04249189727
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 511 that was deleted!
# !!!
# Iteration 20 Objective: 50.21574680249043 move_type merge-split expected_edge_overlap 10014.609158563935
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 483 that was deleted!
# !!!
# Iteration 21 Objective: 50.07032341711428 move_type merge-split expected_edge_overlap 9985.409158563936
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 670 that was deleted!
# !!!
# Iteration 22 Objective: 49.92922622779676 move_type merge-split expected_edge_overlap 9955.909158563936
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 555 that was deleted!
# !!!
# Iteration 23 Objective: 49.78987754162242 move_type merge-split expected_edge_overlap 9927.909158563936
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 632 that was deleted!
# !!!
# Iteration 24 Objective: 49.65263473603042 move_type merge-split expected_edge_overlap 9899.909158563936
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 459 that was deleted!
# !!!
# Iteration 25 Objective: 49.51549124530803 move_type merge-split expected_edge_overlap 9871.85757126235
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 490 that was deleted!
# !!!
# Iteration 26 Objective: 49.37835179760518 move_type merge-split expected_edge_overlap 9844.296965201742
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 513 that was deleted!
# !!!
# Iteration 27 Objective: 49.24326361922661 move_type merge-split expected_edge_overlap 9816.696965201743
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 512 that was deleted!
# !!!
# Iteration 28 Objective: 49.105877794204076 move_type merge-split expected_edge_overlap 9786.830298535078
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 458 that was deleted!
# !!!
# Iteration 29 Objective: 48.97332978667524 move_type merge-split expected_edge_overlap 9759.216388760642
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 628 that was deleted!
# !!!
# Iteration 30 Objective: 48.84290068372948 move_type merge-split expected_edge_overlap 9732.049722093976
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 471 that was deleted!
# !!!
# Iteration 31 Objective: 48.71594601256459 move_type merge-split expected_edge_overlap 9706.372371666626
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 606 that was deleted!
# !!!
# Iteration 32 Objective: 48.589400341827854 move_type merge-split expected_edge_overlap 9680.539038333292
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 544 that was deleted!
# !!!
# Iteration 33 Objective: 48.46375978340285 move_type merge-split expected_edge_overlap 9655.348562142815
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 602 that was deleted!
# !!!
# Iteration 34 Objective: 48.33861611433184 move_type merge-split expected_edge_overlap 9629.072371666625
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 573 that was deleted!
# !!!
# Iteration 35 Objective: 48.215302311247314 move_type merge-split expected_edge_overlap 9604.305704999959
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 560 that was deleted!
# !!!
# Iteration 36 Objective: 48.09302433747055 move_type merge-split expected_edge_overlap 9579.722371666627
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 367 that was deleted!
# !!!
# Iteration 37 Objective: 47.973654460435085 move_type merge-split expected_edge_overlap 9555.7338659195
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 567 that was deleted!
# !!!
# Iteration 38 Objective: 47.85517135334348 move_type merge-split expected_edge_overlap 9531.258865919499
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 552 that was deleted!
# !!!
# Iteration 39 Objective: 47.737288292015336 move_type merge-split expected_edge_overlap 9507.36600877664
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 502 that was deleted!
# !!!
# Iteration 40 Objective: 47.6198124304548 move_type merge-split expected_edge_overlap 9483.712162622796
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 424 that was deleted!
# !!!
# Iteration 41 Objective: 47.50262388716348 move_type merge-split expected_edge_overlap 9460.145495956129
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 419 that was deleted!
# !!!
# Iteration 42 Objective: 47.38560828668088 move_type merge-split expected_edge_overlap 9436.631859592493
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 651 that was deleted!
# !!!
# Iteration 43 Objective: 47.2714495853393 move_type merge-split expected_edge_overlap 9412.881859592493
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 650 that was deleted!
# !!!
# Iteration 44 Objective: 47.083187941141915 move_type merge-split expected_edge_overlap 9369.012811973445
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 422 that was deleted!
# !!!
# Iteration 45 Objective: 46.96926347384718 move_type merge-split expected_edge_overlap 9345.977097687732
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 581 that was deleted!
# !!!
# Iteration 46 Objective: 46.85887872010082 move_type merge-split expected_edge_overlap 9323.012811973445
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 318 that was deleted!
# !!!
# Iteration 47 Objective: 46.74947868090297 move_type merge-split expected_edge_overlap 9300.800690761323
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 482 that was deleted!
# !!!
# Iteration 48 Objective: 46.64151515155092 move_type merge-split expected_edge_overlap 9278.670135205768
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 592 that was deleted!
# !!!
# Iteration 49 Objective: 46.53356729127958 move_type merge-split expected_edge_overlap 9249.423381959015
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 543 that was deleted!
# !!!
# Iteration 50 Objective: 46.42623636115272 move_type merge-split expected_edge_overlap 9227.272191482825
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 481 that was deleted!
# !!!
# Iteration 51 Objective: 46.31953557609151 move_type merge-split expected_edge_overlap 9205.030604181238
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 649 that was deleted!
# !!!
# Iteration 52 Objective: 46.21294243601514 move_type merge-split expected_edge_overlap 9180.09409624473
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 623 that was deleted!
# !!!
# Iteration 53 Objective: 46.10720319568574 move_type merge-split expected_edge_overlap 9158.760762911395
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 469 that was deleted!
# !!!
# Iteration 54 Objective: 46.002509738988664 move_type merge-split expected_edge_overlap 9137.616318466951
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 394 that was deleted!
# !!!
# Iteration 55 Objective: 45.89980633398599 move_type merge-split expected_edge_overlap 9116.906794657429
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 211 that was deleted!
# !!!
# Iteration 56 Objective: 45.79731644620662 move_type merge-split expected_edge_overlap 9096.25976147056
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 345 that was deleted!
# !!!
# Iteration 57 Objective: 45.69543215285685 move_type merge-split expected_edge_overlap 9075.720677289246
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 646 that was deleted!
# !!!
# Iteration 58 Objective: 45.594343840231005 move_type merge-split expected_edge_overlap 9054.470677289246
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 463 that was deleted!
# !!!
# Iteration 59 Objective: 45.49539050945313 move_type merge-split expected_edge_overlap 9034.25420670101
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 237 that was deleted!
# !!!
# Iteration 60 Objective: 45.39655554724695 move_type merge-split expected_edge_overlap 9014.347796444601
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 633 that was deleted!
# !!!
# Iteration 61 Objective: 45.29839731459688 move_type merge-split expected_edge_overlap 8993.597796444601
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 521 that was deleted!
# !!!
# Iteration 62 Objective: 45.20024703645342 move_type merge-split expected_edge_overlap 8973.775826747631
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 556 that was deleted!
# !!!
# Iteration 63 Objective: 45.102105093623805 move_type merge-split expected_edge_overlap 8953.182420154226
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 433 that was deleted!
# !!!
# Iteration 64 Objective: 45.00445035250996 move_type merge-split expected_edge_overlap 8932.909610759463
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 398 that was deleted!
# !!!
# Iteration 65 Objective: 44.907358899149216 move_type merge-split expected_edge_overlap 8913.249512237297
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 520 that was deleted!
# !!!
# Iteration 66 Objective: 44.81041965850838 move_type merge-split expected_edge_overlap 8892.313148600932
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 637 that was deleted!
# !!!
# Iteration 67 Objective: 44.71366536671488 move_type merge-split expected_edge_overlap 8872.063148600932
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 430 that was deleted!
# !!!
# Iteration 68 Objective: 44.617746814412584 move_type merge-split expected_edge_overlap 8852.70142698921
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 448 that was deleted!
# !!!
# Iteration 69 Objective: 44.52244532934614 move_type merge-split expected_edge_overlap 8833.426701714485
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 564 that was deleted!
# !!!
# Iteration 70 Objective: 44.42717694979049 move_type merge-split expected_edge_overlap 8814.293368381152
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 417 that was deleted!
# !!!
# Iteration 71 Objective: 44.33202149611381 move_type merge-split expected_edge_overlap 8795.16260421778
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 618 that was deleted!
# !!!
# Iteration 72 Objective: 44.237411992991525 move_type merge-split expected_edge_overlap 8776.16260421778
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 427 that was deleted!
# !!!
# Iteration 73 Objective: 44.14284635017006 move_type merge-split expected_edge_overlap 8757.146731201907
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 660 that was deleted!
# !!!
# Iteration 74 Objective: 44.04906387890247 move_type merge-split expected_edge_overlap 8735.646731201907
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 385 that was deleted!
# !!!
# Iteration 75 Objective: 43.9557061459347 move_type merge-split expected_edge_overlap 8716.788060460882
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 386 that was deleted!
# !!!
# Iteration 76 Objective: 43.85981443616754 move_type merge-split expected_edge_overlap 8697.127346175168
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 335 that was deleted!
# !!!
# Iteration 77 Objective: 43.766700414933496 move_type merge-split expected_edge_overlap 8678.3981795085
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 659 that was deleted!
# !!!
# Iteration 78 Objective: 43.67417256649486 move_type merge-split expected_edge_overlap 8654.298179508502
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 423 that was deleted!
# !!!
# Iteration 79 Objective: 43.58185824997446 move_type merge-split expected_edge_overlap 8634.707748241653
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 343 that was deleted!
# !!!
# Iteration 80 Objective: 43.49001569285315 move_type merge-split expected_edge_overlap 8616.060610194516
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 344 that was deleted!
# !!!
# Iteration 81 Objective: 43.39795199791797 move_type merge-split expected_edge_overlap 8595.56523006593
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 265 that was deleted!
# !!!
# Iteration 82 Objective: 43.306210825314054 move_type merge-split expected_edge_overlap 8577.075533096233
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 576 that was deleted!
# !!!
# Iteration 83 Objective: 43.21531705982932 move_type merge-split expected_edge_overlap 8558.825533096233
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 538 that was deleted!
# !!!
# Iteration 84 Objective: 43.124564797698014 move_type merge-split expected_edge_overlap 8540.383866429565
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 470 that was deleted!
# !!!
# Iteration 85 Objective: 43.03403861093173 move_type merge-split expected_edge_overlap 8521.157094993117
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 329 that was deleted!
# !!!
# Iteration 86 Objective: 42.943901637517484 move_type merge-split expected_edge_overlap 8502.988415747834
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 351 that was deleted!
# !!!
# Iteration 87 Objective: 42.85382584147865 move_type merge-split expected_edge_overlap 8484.865836572624
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 616 that was deleted!
# !!!
# Iteration 88 Objective: 42.76393913601035 move_type merge-split expected_edge_overlap 8465.490836572624
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 610 that was deleted!
# !!!
# Iteration 89 Objective: 42.675117168734744 move_type merge-split expected_edge_overlap 8447.490836572624
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 611 that was deleted!
# !!!
# Iteration 90 Objective: 42.58493591834525 move_type merge-split expected_edge_overlap 8428.15750323929
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 627 that was deleted!
# !!!
# Iteration 91 Objective: 42.496146076171556 move_type merge-split expected_edge_overlap 8409.65750323929
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 148 that was deleted!
# !!!
# Iteration 92 Objective: 42.40754668083764 move_type merge-split expected_edge_overlap 8391.807795636953
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 645 that was deleted!
# !!!
# Iteration 93 Objective: 42.3194935188601 move_type merge-split expected_edge_overlap 8373.391128970285
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 397 that was deleted!
# !!!
# Iteration 94 Objective: 42.23186612500035 move_type merge-split expected_edge_overlap 8355.264430955656
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 507 that was deleted!
# !!!
# Iteration 95 Objective: 42.1444720832651 move_type merge-split expected_edge_overlap 8336.615926682152
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 266 that was deleted!
# !!!
# Iteration 96 Objective: 42.0572488846783 move_type merge-split expected_edge_overlap 8318.765017314945
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 457 that was deleted!
# !!!
# Iteration 97 Objective: 41.97023265841608 move_type merge-split expected_edge_overlap 8299.408896033481
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 536 that was deleted!
# !!!
# Iteration 98 Objective: 41.883256837571935 move_type merge-split expected_edge_overlap 8281.325562700147
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 537 that was deleted!
# !!!
# Iteration 99 Objective: 41.782214980427966 move_type merge-split expected_edge_overlap 8257.742229366813
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 429 that was deleted!
# !!!
# Iteration 100 Objective: 41.695440597641664 move_type merge-split expected_edge_overlap 8240.034109708695
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 389 that was deleted!
# !!!
# Iteration 101 Objective: 41.60897589582669 move_type merge-split expected_edge_overlap 8222.556549795841
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 123 that was deleted!
# !!!
# Iteration 102 Objective: 41.52253528084043 move_type merge-split expected_edge_overlap 8205.11119103358
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 442 that was deleted!
# !!!
# Iteration 103 Objective: 41.437509617428475 move_type merge-split expected_edge_overlap 8187.89703019442
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 377 that was deleted!
# !!!
# Iteration 104 Objective: 41.35266307871353 move_type merge-split expected_edge_overlap 8170.8565540039435
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 255 that was deleted!
# !!!
# Iteration 105 Objective: 41.26783061781089 move_type merge-split expected_edge_overlap 8153.660200847296
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 362 that was deleted!
# !!!
# Iteration 106 Objective: 41.183067786959896 move_type merge-split expected_edge_overlap 8136.638142023767
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 418 that was deleted!
# !!!
# Iteration 107 Objective: 41.09848187155751 move_type merge-split expected_edge_overlap 8118.884198646618
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 223 that was deleted!
# !!!
# Iteration 108 Objective: 41.013899941557895 move_type merge-split expected_edge_overlap 8101.786777128117
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 303 that was deleted!
# !!!
# Iteration 109 Objective: 40.92995316204917 move_type merge-split expected_edge_overlap 8084.814498304139
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 210 that was deleted!
# !!!
# Iteration 110 Objective: 40.846195693135996 move_type merge-split expected_edge_overlap 8067.309832924474
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 621 that was deleted!
# !!!
# Iteration 111 Objective: 40.76253971966213 move_type merge-split expected_edge_overlap 8050.309832924474
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 622 that was deleted!
# !!!
# Iteration 112 Objective: 40.65453185862276 move_type merge-split expected_edge_overlap 8024.643166257807
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 438 that was deleted!
# !!!
# Iteration 113 Objective: 40.57113695086224 move_type merge-split expected_edge_overlap 8007.6289471435875
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 363 that was deleted!
# !!!
# Iteration 114 Objective: 40.48780688323063 move_type merge-split expected_edge_overlap 7990.74245441229
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 273 that was deleted!
# !!!
# Iteration 115 Objective: 40.405032830121 move_type merge-split expected_edge_overlap 7973.946665707324
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 325 that was deleted!
# !!!
# Iteration 116 Objective: 40.32228161707479 move_type merge-split expected_edge_overlap 7957.279999040658
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 366 that was deleted!
# !!!
# Iteration 117 Objective: 40.23979683727737 move_type merge-split expected_edge_overlap 7940.20966125037
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 190 that was deleted!
# !!!
# Iteration 118 Objective: 40.15764059303689 move_type merge-split expected_edge_overlap 7923.659497046758
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 191 that was deleted!
# !!!
# Iteration 119 Objective: 40.075623347130716 move_type merge-split expected_edge_overlap 7906.926970429417
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 290 that was deleted!
# !!!
# Iteration 120 Objective: 39.99383768967459 move_type merge-split expected_edge_overlap 7890.346162348609
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 161 that was deleted!
# !!!
# Iteration 121 Objective: 39.91236236451823 move_type merge-split expected_edge_overlap 7873.8436833864625
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 270 that was deleted!
# !!!
# Iteration 122 Objective: 39.83093293450332 move_type merge-split expected_edge_overlap 7857.405923733481
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 453 that was deleted!
# !!!
# Iteration 123 Objective: 39.749625323778105 move_type merge-split expected_edge_overlap 7840.821508149065
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 586 that was deleted!
# !!!
# Iteration 124 Objective: 39.6688541295901 move_type merge-split expected_edge_overlap 7824.488174815731
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 587 that was deleted!
# !!!
# Iteration 125 Objective: 39.586648872517515 move_type merge-split expected_edge_overlap 7794.016746244303
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 428 that was deleted!
# !!!
# Iteration 126 Objective: 39.50589774366466 move_type merge-split expected_edge_overlap 7775.595484757252
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 293 that was deleted!
# !!!
# Iteration 127 Objective: 39.42522892109315 move_type merge-split expected_edge_overlap 7759.1609200985495
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 523 that was deleted!
# !!!
# Iteration 128 Objective: 39.3446305791453 move_type merge-split expected_edge_overlap 7742.547366984996
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 393 that was deleted!
# !!!
# Iteration 129 Objective: 39.26420600373052 move_type merge-split expected_edge_overlap 7725.942605080235
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 444 that was deleted!
# !!!
# Iteration 130 Objective: 39.1840566436768 move_type merge-split expected_edge_overlap 7709.460667477608
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 412 that was deleted!
# !!!
# Iteration 131 Objective: 39.103999112685415 move_type merge-split expected_edge_overlap 7693.35559501384
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 503 that was deleted!
# !!!
# Iteration 132 Objective: 39.02401122190986 move_type merge-split expected_edge_overlap 7676.866584024829
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 310 that was deleted!
# !!!
# Iteration 133 Objective: 38.944443330306285 move_type merge-split expected_edge_overlap 7660.778656063675
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 308 that was deleted!
# !!!
# Iteration 134 Objective: 38.86529004593507 move_type merge-split expected_edge_overlap 7644.8283407950985
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 234 that was deleted!
# !!!
# Iteration 135 Objective: 38.78621436107875 move_type merge-split expected_edge_overlap 7628.863597205355
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 408 that was deleted!
# !!!
# Iteration 136 Objective: 38.70726036119987 move_type merge-split expected_edge_overlap 7612.906360977531
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 354 that was deleted!
# !!!
# Iteration 137 Objective: 38.62835074378137 move_type merge-split expected_edge_overlap 7596.752057304995
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 160 that was deleted!
# !!!
# Iteration 138 Objective: 38.5495055276146 move_type merge-split expected_edge_overlap 7580.284176810295
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 167 that was deleted!
# !!!
# Iteration 139 Objective: 38.47073117985792 move_type merge-split expected_edge_overlap 7564.296391907876
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 174 that was deleted!
# !!!
# Iteration 140 Objective: 38.39200294646224 move_type merge-split expected_edge_overlap 7548.387544390621
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 466 that was deleted!
# !!!
# Iteration 141 Objective: 38.31330889086922 move_type merge-split expected_edge_overlap 7532.46590696372
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 117 that was deleted!
# !!!
# Iteration 142 Objective: 38.23461844429687 move_type merge-split expected_edge_overlap 7516.582567337095
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 276 that was deleted!
# !!!
# Iteration 143 Objective: 38.15605760804294 move_type merge-split expected_edge_overlap 7500.713339342866
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 28 that was deleted!
# !!!
# Iteration 144 Objective: 38.0780998695933 move_type merge-split expected_edge_overlap 7484.958482201713
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 686 that was deleted!
# !!!
# Iteration 145 Objective: 38.000162853445204 move_type merge-split expected_edge_overlap 7459.291815535046
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 231 that was deleted!
# !!!
# Iteration 146 Objective: 37.9225280231617 move_type merge-split expected_edge_overlap 7443.612773550747
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 230 that was deleted!
# !!!
# Iteration 147 Objective: 37.84168847370074 move_type merge-split expected_edge_overlap 7427.027212053422
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 224 that was deleted!
# !!!
# Iteration 148 Objective: 37.76406887069629 move_type merge-split expected_edge_overlap 7411.062452517766
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 238 that was deleted!
# !!!
# Iteration 149 Objective: 37.68646520994673 move_type merge-split expected_edge_overlap 7395.018891911705
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 251 that was deleted!
# !!!
# Iteration 150 Objective: 37.608946913152465 move_type merge-split expected_edge_overlap 7379.343287716539
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 603 that was deleted!
# !!!
# Iteration 151 Objective: 37.53192224660614 move_type merge-split expected_edge_overlap 7363.143287716539
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 309 that was deleted!
# !!!
# Iteration 152 Objective: 37.455160179043276 move_type merge-split expected_edge_overlap 7346.468508571387
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 506 that was deleted!
# !!!
# Iteration 153 Objective: 37.37839859005345 move_type merge-split expected_edge_overlap 7329.986457289336
# !!!
# ...
# !!!
# Iteration 1981 Objective: 0.5529063332076974 move_type merge-split expected_edge_overlap 8415.492534689596
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# Iteration 1982 Objective: 0.5529038729275263 move_type merge-split expected_edge_overlap 8415.513202575527
# Iteration 1983 Objective: 0.5529026053930283 move_type swap expected_edge_overlap 8415.468223355087
# Iteration 1984 Objective: 0.5529014155064246 move_type swap expected_edge_overlap 8415.301315902954
# Iteration 1985 Objective: 0.552900442258012 move_type split expected_edge_overlap 8415.383702455343
# Iteration 1986 Objective: 0.5528990463095479 move_type swap expected_edge_overlap 8415.454744948587
# Iteration 1987 Objective: 0.5528980758825794 move_type swap expected_edge_overlap 8415.339409450751
# Iteration 1988 Objective: 0.5528971585665394 move_type swap expected_edge_overlap 8415.411219970949
# Iteration 1989 Objective: 0.5528965942383125 move_type swap expected_edge_overlap 8415.48381104028
# Iteration 1990 Objective: 0.5528960342512761 move_type swap expected_edge_overlap 8415.427207474353
# Iteration 1991 Objective: 0.5528954872070269 move_type swap expected_edge_overlap 8415.42563298645
# Iteration 1992 Objective: 0.5528942917087151 move_type split expected_edge_overlap 8415.493334849803
# Iteration 1993 Objective: 0.5528938068550606 move_type swap expected_edge_overlap 8415.360215119945
# Iteration 1994 Objective: 0.5528932372715597 move_type swap expected_edge_overlap 8415.216828805591
# Iteration 1995 Objective: 0.5528917855513934 move_type split expected_edge_overlap 8415.216828805591
# Iteration 1996 Objective: 0.5528917126553717 move_type split expected_edge_overlap 8415.216828805591
# Iteration 1997 Objective: 0.5528916506057681 move_type split expected_edge_overlap 8415.216828805591
# Iteration 1998 Objective: 0.5528916208808531 move_type split expected_edge_overlap 8415.216828805591
# Iteration 1999 Objective: 0.5528915943670258 move_type swap expected_edge_overlap 8415.374468098931
# Iteration 2000 Objective: 0.5528913717748083 move_type split expected_edge_overlap 8415.374468098931
# Iteration 2001 Objective: 0.5528913468622427 move_type swap expected_edge_overlap 8415.379156811863
# Iteration 2002 Objective: 0.5528904195908504 move_type swap expected_edge_overlap 8415.494946285547
# Iteration 2003 Objective: 0.5528903952875732 move_type split expected_edge_overlap 8415.494946285547
# Iteration 2004 Objective: 0.5528903715403917 move_type split expected_edge_overlap 8415.494946285547
# Iteration 2005 Objective: 0.5528903478163529 move_type split expected_edge_overlap 8415.494946285547
# Iteration 2006 Objective: 0.5528903246662223 move_type swap expected_edge_overlap 8415.468877880692
# Iteration 2007 Objective: 0.552890301678305 move_type split expected_edge_overlap 8415.468877880692
# Iteration 2008 Objective: 0.5528902796230918 move_type split expected_edge_overlap 8415.468877880692
# Iteration 2009 Objective: 0.5528902583034275 move_type split expected_edge_overlap 8415.468877880692
# Iteration 2010 Objective: 0.5528902381273041 move_type swap expected_edge_overlap 8415.421303629248
# Iteration 2011 Objective: 0.5528902179619184 move_type swap expected_edge_overlap 8415.479485016886
# Iteration 2012 Objective: 0.5528901985685241 move_type swap expected_edge_overlap 8415.517580254982
# Iteration 2013 Objective: 0.5528899475250119 move_type split expected_edge_overlap 8415.517580254982
# Iteration 2014 Objective: 0.5528898307408012 move_type swap expected_edge_overlap 8415.556795941256
# Iteration 2015 Objective: 0.5528898120423167 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2016 Objective: 0.5528897945939735 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2017 Objective: 0.5528897774118435 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2018 Objective: 0.5528897603321898 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2019 Objective: 0.5528897448292958 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2020 Objective: 0.5528897307223171 move_type split expected_edge_overlap 8415.556795941256
# Iteration 2021 Objective: 0.5528897173096614 move_type swap expected_edge_overlap 8415.561854157506
# Iteration 2022 Objective: 0.5528897044551528 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2023 Objective: 0.5528896920316497 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2024 Objective: 0.5528896801865133 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2025 Objective: 0.5528896695139092 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2026 Objective: 0.5528896596498112 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2027 Objective: 0.5528896502207346 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2028 Objective: 0.5528896412982807 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2029 Objective: 0.5528896328181725 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2030 Objective: 0.5528896254920164 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2031 Objective: 0.5528896185407759 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2032 Objective: 0.5528896116724424 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2033 Objective: 0.5528896052191707 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2034 Objective: 0.5528895990853262 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2035 Objective: 0.5528895930387754 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2036 Objective: 0.5528895872009643 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2037 Objective: 0.5528895817811308 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2038 Objective: 0.5528895782329872 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2039 Objective: 0.552889575236228 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2040 Objective: 0.552889572282337 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2041 Objective: 0.5528895693302833 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2042 Objective: 0.5528895664007734 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2043 Objective: 0.5528895635750404 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2044 Objective: 0.5528895608483553 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2045 Objective: 0.5528895583674793 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2046 Objective: 0.5528895560251272 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2047 Objective: 0.5528895538350187 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2048 Objective: 0.5528895518636427 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2049 Objective: 0.5528895501899869 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2050 Objective: 0.5528895485376419 move_type split expected_edge_overlap 8415.561854157506
# Iteration 2051 Objective: 0.5528895469988933 move_type swap expected_edge_overlap 8415.511189669489
# Iteration 2052 Objective: 0.5528895454613107 move_type split expected_edge_overlap 8415.511189669489
# Iteration 2053 Objective: 0.5528895199497783 move_type swap expected_edge_overlap 8415.567729676795
# Iteration 2054 Objective: 0.5528893121981691 move_type split expected_edge_overlap 8415.567729676795
# Iteration 2055 Objective: 0.5528893107051958 move_type split expected_edge_overlap 8415.567729676795
# Iteration 2056 Objective: 0.5528893092414635 move_type split expected_edge_overlap 8415.567729676795
# Iteration 2057 Objective: 0.552889307786995 move_type split expected_edge_overlap 8415.567729676795
# Iteration 2058 Objective: 0.5528893064573444 move_type split expected_edge_overlap 8415.567729676795
# Iteration 2059 Objective: 0.5528893054022851 move_type swap expected_edge_overlap 8415.56336708901
# Iteration 2060 Objective: 0.5528893043521806 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2061 Objective: 0.5528893033021375 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2062 Objective: 0.5528893022635154 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2063 Objective: 0.5528893012574646 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2064 Objective: 0.5528893003455492 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2065 Objective: 0.5528892994387696 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2066 Objective: 0.552889298532181 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2067 Objective: 0.5528892977317063 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2068 Objective: 0.5528892969874278 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2069 Objective: 0.5528892962492379 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2070 Objective: 0.5528892956057624 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2071 Objective: 0.5528892949630236 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2072 Objective: 0.5528892943275231 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2073 Objective: 0.5528892937990498 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2074 Objective: 0.5528892933173032 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2075 Objective: 0.5528892929271806 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2076 Objective: 0.5528892925794627 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2077 Objective: 0.5528892923331549 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2078 Objective: 0.5528892921136171 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2079 Objective: 0.5528892919159069 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2080 Objective: 0.5528892917309277 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2081 Objective: 0.5528892915730602 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2082 Objective: 0.552889291425175 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2083 Objective: 0.5528892913024913 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2084 Objective: 0.5528892912029745 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2085 Objective: 0.5528892911337183 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2086 Objective: 0.5528892910834141 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2087 Objective: 0.5528892910460604 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2088 Objective: 0.5528892910095878 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2089 Objective: 0.5528892909758131 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2090 Objective: 0.5528892909559214 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2091 Objective: 0.5528892909371609 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2092 Objective: 0.5528892909199213 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2093 Objective: 0.5528892909112336 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2094 Objective: 0.5528892909071418 move_type split expected_edge_overlap 8415.56336708901
# Iteration 2095 Objective: 0.5528892909036832 move_type split expected_edge_overlap 8415.56336708901
# Doing dist=2
# Iteration 0 Objective: 0.5528101564724203 move_type merge-split expected_edge_overlap 8412.862728519405
# Iteration 1 Objective: 0.5527983948458761 move_type swap expected_edge_overlap 8412.455321111998
# Iteration 2 Objective: 0.5527893739650375 move_type merge-split expected_edge_overlap 8412.564728371406
# Iteration 3 Objective: 0.5527815548577095 move_type merge-split expected_edge_overlap 8412.674315597273
# Iteration 4 Objective: 0.5527785186095344 move_type swap expected_edge_overlap 8412.32661529442
# Iteration 5 Objective: 0.5527749781057522 move_type swap expected_edge_overlap 8412.340829958523
# Iteration 6 Objective: 0.5527732385062128 move_type swap expected_edge_overlap 8412.313896927371
# Iteration 7 Objective: 0.5527714315517934 move_type swap expected_edge_overlap 8412.284008690338
# Iteration 8 Objective: 0.5527697557406114 move_type split expected_edge_overlap 8412.340969273615
# Iteration 9 Objective: 0.5527685802263822 move_type swap expected_edge_overlap 8412.3787534977
# Iteration 10 Objective: 0.5527670183843509 move_type merge-split expected_edge_overlap 8412.291788646471
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 330 that was deleted!
# !!!
# Iteration 11 Objective: 0.5527661362392065 move_type merge-split expected_edge_overlap 8411.770624625307
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# Iteration 12 Objective: 0.5527631329855311 move_type merge-split expected_edge_overlap 8411.83087696556
# Iteration 13 Objective: 0.5527612064134475 move_type swap expected_edge_overlap 8411.826295844698
# Iteration 14 Objective: 0.5527605316257967 move_type swap expected_edge_overlap 8411.8841260552
# Iteration 15 Objective: 0.5527598673206396 move_type swap expected_edge_overlap 8411.942845961248
# Iteration 16 Objective: 0.5527593880527013 move_type swap expected_edge_overlap 8412.065475544056
# Iteration 17 Objective: 0.5527589500411342 move_type swap expected_edge_overlap 8411.981393207963
# Iteration 18 Objective: 0.5527585275020931 move_type swap expected_edge_overlap 8412.079683806254
# Iteration 19 Objective: 0.5527581238605351 move_type swap expected_edge_overlap 8411.971933418503
# Iteration 20 Objective: 0.5527566460709528 move_type swap expected_edge_overlap 8412.016903712283
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 190 that was deleted!
# !!!
# Iteration 21 Objective: 0.5527559885170268 move_type merge-split expected_edge_overlap 8411.80243433407
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# Iteration 22 Objective: 0.5527550035987749 move_type swap expected_edge_overlap 8411.881953879507
# Iteration 23 Objective: 0.5527548685659102 move_type swap expected_edge_overlap 8411.906748522611
# Iteration 24 Objective: 0.5527547533395669 move_type swap expected_edge_overlap 8411.925602612366
# Iteration 25 Objective: 0.5527546715587891 move_type swap expected_edge_overlap 8411.994156071487
# Iteration 26 Objective: 0.5527546118708014 move_type swap expected_edge_overlap 8411.874692549534
# Iteration 27 Objective: 0.5527545698984621 move_type split expected_edge_overlap 8411.874692549534
# Iteration 28 Objective: 0.552754528056552 move_type swap expected_edge_overlap 8411.997875229685
# Iteration 29 Objective: 0.552754491670481 move_type split expected_edge_overlap 8411.997875229685
# Iteration 30 Objective: 0.5527544722093256 move_type split expected_edge_overlap 8411.997875229685
# Iteration 31 Objective: 0.5527544558562233 move_type swap expected_edge_overlap 8412.047421071315
# Iteration 32 Objective: 0.5527544399179677 move_type swap expected_edge_overlap 8411.958430855364
# !!!
# TODO THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!! Cluster 24 that was deleted!
# !!!
# Iteration 33 Objective: 0.5527543699393137 move_type merge-split expected_edge_overlap 8411.891085894124
# !!!
# TODO DELETING CLUSTERS: THIS CODE ISN'T WELL TESTED CLUSTERS ARE ALMOST NEVER EXECUTED!!!
# !!!
# Iteration 34 Objective: 0.5527543018870259 move_type swap expected_edge_overlap 8411.885162607505
# Iteration 35 Objective: 0.5527542976218697 move_type split expected_edge_overlap 8411.885162607505
# Iteration 36 Objective: 0.5527542975680803 move_type split expected_edge_overlap 8411.885162607505
# Doing dist=3
# Done w=5e-05

# %%
from utils.colour_refinement_out_neigh_algorithm import colour_refinement_out_neigh_algorithm

for d in range(3):
    clusters = colour_refinement_out_neigh_algorithm(A_G, d)
    print(f"Done depth {d}")
    df.loc[len(df)] = evaluate_cluster_assignment(katz_centrality, A_G, clusters) + [f"Out-NeSt Model (d={d})"]
# Out:
# Done depth 0
# Done depth 1
# Done depth 2

# %%
dfplot = df.copy()
dfplot["is_pareto_front"] = is_pareto_front(df[['ell_sqr', 'expected_edge_overlap']].values)

# %%
import pandas as pd
import plotly.express as px

def get_method_type_name(method_type):
    if 'Kmeans' in method_type:
        return 'Kmeans'
    elif 'Warm Start Greedy Search' in method_type:
        return 'Warm Start Greedy Search'
    elif 'Greedy Search' in method_type:
        return 'Greedy Search'
    elif 'Opt. Cont. Scal.' in method_type:
        return 'Opt. Cont. Scal.'
    elif 'Out-NeSt Model' in method_type:
        return 'Out-NeSt Model'
    else:
        return 'Other'

dfplot['method_type_name'] = dfplot['method_type'].apply(get_method_type_name)
dfplot['(Expected Edge Overlap)/|E|'] = dfplot['expected_edge_overlap'] / G.number_of_edges()

# Determining shape based on is_pareto_front
dfplot['shape'] = dfplot['is_pareto_front'].apply(lambda x: 'circle-open' if x else 'square-open')

# Plotting with Plotly
fig = px.scatter(
    dfplot,
    x='ell_sqr',
    y='(Expected Edge Overlap)/|E|',
    hover_data=['method_type'],
    symbol='shape',
    color='method_type_name',
    symbol_sequence=['circle-open', 'square-open']
)

fig.update_traces(marker=dict(size=10, line=dict(width=2)))

# Updating layout for legend
fig.update_layout(
    height=800,
    legend_title_text='Method Type',
    legend=dict(
        title='Method Type',
        itemsizing='constant',
        traceorder='normal',
        font=dict(size=10)
    )
)

fig.show()

# %%
fig.update_xaxes(type='log', tickformat=".0e")
fig.show()
